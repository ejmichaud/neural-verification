# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from model import RNN

### Preparation ####

# set random seed
seed = 3
np.random.seed(seed)
torch.manual_seed(seed)

# set precision and device
torch.set_default_dtype(torch.float)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

### load dataset ###


def load_data(mode='train'):
    data = np.loadtxt('./data_{}.txt'.format(mode), dtype='str')
    inputs = data[:,:2]
    labels = data[:,2]

    def strs2mat(strings):
        num = strings.shape[0]
        mat = []
        for i in range(num):
            mat.append([*strings[i]])
        return mat

    inputs_ = np.transpose(np.array([strs2mat(inputs[:,0]), strs2mat(inputs[:,1])]), (1,2,0)).astype('float')
    labels_ = np.array(strs2mat(labels))[:,:,np.newaxis].astype('float')

    return inputs_, labels_

inputs_train, labels_train = load_data(mode='train')
inputs_test, labels_test = load_data(mode='test')

inputs_train = torch.tensor(inputs_train, dtype=torch.float, requires_grad=True).to(device)
labels_train = torch.tensor(labels_train, dtype=torch.float, requires_grad=True).to(device)
inputs_test = torch.tensor(inputs_test, dtype=torch.float, requires_grad=True).to(device)
labels_test = torch.tensor(labels_test, dtype=torch.float, requires_grad=True).to(device)

def l1(model):
    l1_reg = torch.tensor(0.).to(device)
    for param in model.parameters():
        l1_reg += torch.sum(torch.abs(param))
    return l1_reg
    

model = RNN(hidden_dim=1, device=device).to(device)
# Out:
# cuda

# %%
### Training ###

optimizer = torch.optim.AdamW(model.parameters(), lr=0.01, weight_decay=0.0)
steps = 10001
log = 200
lamb = 0e-4

for step in range(steps):
    
    optimizer.zero_grad()
    
    pred_train = model(inputs_train)
    loss_train = torch.mean((pred_train-labels_train)**2)
    acc_train = 1-loss_train

    pred_test = model(inputs_test)
    loss_test = torch.mean((pred_test-labels_test)**2)
    acc_test = 1-loss_test
    
    reg = l1(model)
    loss = loss_train + lamb * reg
    
    loss.backward()
    optimizer.step()
    
    if step % log == 0:
        print("step = %d | train loss: %.2e | test loss %.2e | train acc: %.2e | test acc: %.2e | reg: %.2e "%(step, loss_train.cpu().detach().numpy(), loss_test.cpu().detach().numpy(), acc_train.cpu().detach().numpy(), acc_test.cpu().detach().numpy(), reg.cpu().detach().numpy()))
    
torch.save(model.state_dict(), './model')
# Out:
# step = 0 | train loss: 7.92e-01 | test loss 7.88e-01 | train acc: 2.08e-01 | test acc: 2.12e-01 | reg: 3.38e+00
# step = 200 | train loss: 1.27e-01 | test loss 1.30e-01 | train acc: 8.73e-01 | test acc: 8.70e-01 | reg: 4.82e+00
# step = 400 | train loss: 3.34e-02 | test loss 3.45e-02 | train acc: 9.67e-01 | test acc: 9.65e-01 | reg: 8.92e+00
# step = 600 | train loss: 9.49e-03 | test loss 9.11e-03 | train acc: 9.91e-01 | test acc: 9.91e-01 | reg: 1.16e+01
# step = 800 | train loss: 4.58e-03 | test loss 4.28e-03 | train acc: 9.95e-01 | test acc: 9.96e-01 | reg: 1.30e+01
# step = 1000 | train loss: 2.79e-03 | test loss 2.57e-03 | train acc: 9.97e-01 | test acc: 9.97e-01 | reg: 1.40e+01
# step = 1200 | train loss: 1.91e-03 | test loss 1.75e-03 | train acc: 9.98e-01 | test acc: 9.98e-01 | reg: 1.47e+01
# step = 1400 | train loss: 1.40e-03 | test loss 1.27e-03 | train acc: 9.99e-01 | test acc: 9.99e-01 | reg: 1.53e+01
# step = 1600 | train loss: 1.07e-03 | test loss 9.71e-04 | train acc: 9.99e-01 | test acc: 9.99e-01 | reg: 1.58e+01
# step = 1800 | train loss: 8.44e-04 | test loss 7.65e-04 | train acc: 9.99e-01 | test acc: 9.99e-01 | reg: 1.63e+01
# step = 2000 | train loss: 6.82e-04 | test loss 6.17e-04 | train acc: 9.99e-01 | test acc: 9.99e-01 | reg: 1.67e+01
# step = 2200 | train loss: 5.62e-04 | test loss 5.07e-04 | train acc: 9.99e-01 | test acc: 9.99e-01 | reg: 1.71e+01
# step = 2400 | train loss: 4.69e-04 | test loss 4.23e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.75e+01
# step = 2600 | train loss: 3.96e-04 | test loss 3.56e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.78e+01
# step = 2800 | train loss: 3.37e-04 | test loss 3.03e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.81e+01
# step = 3000 | train loss: 2.90e-04 | test loss 2.60e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.84e+01
# step = 3200 | train loss: 2.51e-04 | test loss 2.25e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.87e+01
# step = 3400 | train loss: 2.18e-04 | test loss 1.95e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.90e+01
# step = 3600 | train loss: 1.90e-04 | test loss 1.71e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.93e+01
# step = 3800 | train loss: 1.67e-04 | test loss 1.50e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.95e+01
# step = 4000 | train loss: 1.47e-04 | test loss 1.32e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 1.98e+01
# step = 4200 | train loss: 1.30e-04 | test loss 1.16e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.00e+01
# step = 4400 | train loss: 1.15e-04 | test loss 1.03e-04 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.03e+01
# step = 4600 | train loss: 1.02e-04 | test loss 9.11e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.05e+01
# step = 4800 | train loss: 9.06e-05 | test loss 8.10e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.07e+01
# step = 5000 | train loss: 8.08e-05 | test loss 7.21e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.10e+01
# step = 5200 | train loss: 7.21e-05 | test loss 6.43e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.12e+01
# step = 5400 | train loss: 6.44e-05 | test loss 5.75e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.14e+01
# step = 5600 | train loss: 5.76e-05 | test loss 5.14e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.16e+01
# step = 5800 | train loss: 5.16e-05 | test loss 4.60e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.19e+01
# step = 6000 | train loss: 4.63e-05 | test loss 4.13e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.21e+01
# step = 6200 | train loss: 4.16e-05 | test loss 3.70e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.23e+01
# step = 6400 | train loss: 3.73e-05 | test loss 3.33e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.25e+01
# step = 6600 | train loss: 3.36e-05 | test loss 2.99e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.27e+01
# step = 6800 | train loss: 3.02e-05 | test loss 2.69e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.29e+01
# step = 7000 | train loss: 2.72e-05 | test loss 2.42e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.32e+01
# step = 7200 | train loss: 2.45e-05 | test loss 2.18e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.34e+01
# step = 7400 | train loss: 2.20e-05 | test loss 1.96e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.36e+01
# step = 7600 | train loss: 1.99e-05 | test loss 1.77e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.38e+01
# step = 7800 | train loss: 1.79e-05 | test loss 1.60e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.40e+01
# step = 8000 | train loss: 1.62e-05 | test loss 1.44e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.42e+01
# step = 8200 | train loss: 1.46e-05 | test loss 1.30e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.44e+01
# step = 8400 | train loss: 1.32e-05 | test loss 1.17e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.46e+01
# step = 8600 | train loss: 1.19e-05 | test loss 1.06e-05 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.48e+01
# step = 8800 | train loss: 1.07e-05 | test loss 9.55e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.50e+01
# step = 9000 | train loss: 9.70e-06 | test loss 8.62e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.52e+01
# step = 9200 | train loss: 8.87e-06 | test loss 7.88e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.54e+01
# step = 9400 | train loss: 8.21e-06 | test loss 7.31e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.56e+01
# step = 9600 | train loss: 7.59e-06 | test loss 6.76e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.57e+01
# step = 9800 | train loss: 7.12e-06 | test loss 6.33e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.58e+01
# step = 10000 | train loss: 6.69e-06 | test loss 5.95e-06 | train acc: 1.00e+00 | test acc: 1.00e+00 | reg: 2.60e+01

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from model import RNN

# Load the trained model
model.load_state_dict(torch.load('./model'))

# Visualize the weights with values
def visualize_weights_with_values(model):
    for name, param in model.named_parameters():
        if 'weight' in name:  # We're interested in weight parameters
            plt.figure()
            plt.title(f'Weights for {name}')
            weights = param.detach().cpu().numpy()
            plt.imshow(weights, cmap='viridis', aspect='auto')
            plt.colorbar()
            for i in range(weights.shape[0]):
                for j in range(weights.shape[1]):
                    plt.text(j, i, f'{weights[i, j]:.2f}', ha='center', va='center', color='r', fontsize=8)
            plt.show()

# Call the function to visualize the weights with values
visualize_weights_with_values(model)

# %%
# Load your trained model (if not already loaded)
# model = RNN(hidden_dim=2, device=device).to(device)
device="cuda"
model.load_state_dict(torch.load('./model'))

# Define a function to test the model
# Define a function to test the model
def test_model(model, inputs, labels):
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        inputs = inputs.to(device)  # Ensure inputs are on the same device as the model
        labels = labels.to(device)  # Ensure labels are on the same device as the model
        pred = model(inputs)
        loss = torch.mean((pred - labels)**2)
        print(inputs[0], labels[0], pred[0])
        accuracy = (1-loss).to(torch.float)

    return loss, accuracy


# Test the model on the test dataset
test_loss, test_accuracy = test_model(model, inputs_test, labels_test)

print(f"Test Loss: {test_loss.item():.4f}")
print(f"Test Accuracy: {test_accuracy.item() * 100:.2f}%")
# Out:
# tensor([[1., 0.]], device='cuda:0', requires_grad=True) tensor([[0.]], device='cuda:0', requires_grad=True) tensor([[0.0021]], device='cuda:0')
# Test Loss: 0.0000
# Test Accuracy: 100.00%

# %%
sample_input = inputs_test[0:1,:]

with torch.no_grad():
     result = model(sample_input)
